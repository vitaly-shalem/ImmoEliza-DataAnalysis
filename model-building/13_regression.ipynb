# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#   load data
df = pd.read_csv("..\\data\\05_ml_data.csv", index_col="ID")

# %%
df.head(10)
# Out:
#           typeNum  region_Brussels  region_Flanders  region_Wallonie  \
# ID
# 10616910        0              0.0              1.0              0.0
# 10616880        0              0.0              1.0              0.0
# 10616933        0              0.0              1.0              0.0
# 10616913        0              0.0              1.0              0.0
# 10616926        0              0.0              0.0              1.0
# 10616911        0              0.0              0.0              1.0
# 10616934        0              0.0              0.0              1.0
# 10616833        0              0.0              0.0              1.0
# 10616966        0              0.0              1.0              0.0
# 10485868        0              0.0              0.0              1.0
#
#           province_Antwerp  province_Brussels  province_East Flanders  \
# ID
# 10616910               0.0                0.0                     0.0
# 10616880               1.0                0.0                     0.0
# 10616933               0.0                0.0                     0.0
# 10616913               1.0                0.0                     0.0
# 10616926               0.0                0.0                     0.0
# 10616911               0.0                0.0                     0.0
# 10616934               0.0                0.0                     0.0
# 10616833               0.0                0.0                     0.0
# 10616966               1.0                0.0                     0.0
# 10485868               0.0                0.0                     0.0
#
#           province_Flemish Brabant  province_Hainaut  province_Limburg  ...  \
# ID                                                                      ...
# 10616910                       0.0               0.0               1.0  ...
# 10616880                       0.0               0.0               0.0  ...
# 10616933                       0.0               0.0               0.0  ...
# 10616913                       0.0               0.0               0.0  ...
# 10616926                       0.0               0.0               0.0  ...
# 10616911                       0.0               0.0               0.0  ...
# 10616934                       0.0               0.0               0.0  ...
# 10616833                       0.0               0.0               0.0  ...
# 10616966                       0.0               0.0               0.0  ...
# 10485868                       0.0               1.0               0.0  ...
#
#           hasLift  fireplaceExists  hasSwimmingPool  hasAirConditioning  \
# ID
# 10616910        1                0                0                   0
# 10616880        0                0                0                   0
# 10616933        1                0                0                   0
# 10616913        1                0                0                   0
# 10616926        0                1                0                   0
# 10616911        1                0                0                   0
# 10616934        0                0                0                   0
# 10616833        1                0                0                   0
# 10616966        0                0                0                   0
# 10485868        0                0                0                   0
#
#           hasGarden  hasTerrace  sc_gardenSurface  sc_terraceSurface  sc_land  \
# ID
# 10616910          0           1              0.00               0.24      0.0
# 10616880          0           1              0.00               0.00      0.0
# 10616933          0           0              0.00               0.00      0.0
# 10616913          1           1              0.00               0.01      0.0
# 10616926          1           0              0.09               0.00      0.0
# 10616911          0           1              0.00               0.00      0.0
# 10616934          0           0              0.00               0.00      0.0
# 10616833          0           1              0.00               0.09      0.0
# 10616966          0           0              0.00               0.00      0.0
# 10485868          0           1              0.00               0.11      0.0
#
#              price
# ID
# 10616910  399000.0
# 10616880  218000.0
# 10616933   95000.0
# 10616913  359000.0
# 10616926  165000.0
# 10616911  423000.0
# 10616934  169000.0
# 10616833  275000.0
# 10616966  185000.0
# 10485868  205186.0
#
# [10 rows x 36 columns]

# %%
X = df.drop("price", axis=1).to_numpy()
y = df["price"].to_numpy()
print(X.shape, y.shape)
# Out:
# (16292, 35) (16292,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of X_train:  (13033, 35)
# Shape of X_test:  (3259, 35)
# Shape of y_train:  (13033,)
# Shape of y_test:  (3259,)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.4613157914170799

# %%
model.score(X_test, y_test)
# Out:
# 0.43622747836046305
