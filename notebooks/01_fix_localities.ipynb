# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import json

# %%
# load data
path_to_open = "..\\data\\_properties_data.json"

data = None
with open(path_to_open, "r", encoding="utf-8") as file:
    data = json.load(file)

df = pd.DataFrame.from_dict(data, orient='index')

df.head()
# Out:
#                                                     URL  Status  \
# 10616910  https://www.immoweb.be/en/classified/10616910     200
# 10616880  https://www.immoweb.be/en/classified/10616880     200
# 10616933  https://www.immoweb.be/en/classified/10616933     200
# 10616917  https://www.immoweb.be/en/classified/10616917     200
# 10616913  https://www.immoweb.be/en/classified/10616913     200
#
#          transactionType transactionSubtype     price       type    subtype  \
# 10616910        FOR_SALE        BUY_REGULAR  399000.0  APARTMENT  APARTMENT
# 10616880        FOR_SALE        BUY_REGULAR  218000.0  APARTMENT  APARTMENT
# 10616933        FOR_SALE        BUY_REGULAR   95000.0  APARTMENT  APARTMENT
# 10616917        FOR_SALE        BUY_REGULAR  169000.0  APARTMENT  APARTMENT
# 10616913        FOR_SALE        BUY_REGULAR  359000.0  APARTMENT  APARTMENT
#
#           country    region       province  ... toiletCount  \
# 10616910  Belgium  Flanders        Limburg  ...         1.0
# 10616880  Belgium  Flanders        Antwerp  ...         1.0
# 10616933  Belgium  Flanders  West Flanders  ...         1.0
# 10616917  Belgium  Flanders  West Flanders  ...         NaN
# 10616913  Belgium  Flanders        Antwerp  ...         NaN
#
#          parkingCountIndoor parkingCountOutdoor parkingCountClosedBox  \
# 10616910                1.0                 1.0                  None
# 10616880                NaN                 NaN                  None
# 10616933                NaN                 NaN                  None
# 10616917                NaN                 NaN                  None
# 10616913                NaN                 NaN                  None
#
#          primaryEnergyConsumptionPerSqm epcScore  hasDoubleGlazing  saleType  \
# 10616910                          142.0        B              True      None
# 10616880                           92.0        A              True      None
# 10616933                          521.0        F              None      None
# 10616917                          391.0        D              True      None
# 10616913                          140.0        B             False      None
#
#                           creationDate          lastModificationDate
# 10616910  2023-06-07T07:39:57.000+0000  2023-06-07T07:39:59.080+0000
# 10616880  2023-06-07T07:22:33.000+0000  2023-07-05T08:30:20.607+0000
# 10616933  2023-06-07T07:52:35.000+0000  2023-07-05T08:28:15.563+0000
# 10616917  2023-06-07T07:47:23.000+0000  2023-07-05T08:19:08.357+0000
# 10616913  2023-06-07T07:44:08.000+0000  2023-06-07T07:44:09.170+0000
#
# [5 rows x 47 columns]

# %%
ref_postalCode_locality_data = pd.read_csv("..\data\_postal_code_data.csv")
ref_postalCode_locality_data.head()
# Out:
#    postalCode          city  municipality   latitude  longtitude  cityAltName
# 0        1000       Brussel       Brussel  50.822285    4.381571    Bruxelles
# 1        1030    Schaarbeek    Schaarbeek  50.822285    4.381571   Schaerbeek
# 2        1040     Etterbeek     Etterbeek  50.822285    4.381571          NaN
# 3        1050       Ixelles       Ixelles  50.822285    4.381571       Elsene
# 4        1060  Saint-Gilles  Saint-Gilles  50.822285    4.381571  Sint-Gillis

# %%
# iterate

# %%
# save csv
path_to_save = "..\\data\\01_fixLocality_properties_data.csv"
df.to_csv(path_to_save)
